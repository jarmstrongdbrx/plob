-- %%
SELECT PX.coveragecd, PX.subcoveragecd, PX.state, PX.asl, PX.subline, PX.pas_key_prefix, PX.pd_lob, PX.plob, CX.plob_description, PX.alternate_asl, PX.alternate_sbl
FROM prod_lakehouse.dev_john_armstrong_policy.COVCD_PLOB_XREF PX
JOIN prod_lakehouse.dev_john_armstrong_policy.COVERAGE_LOB_XREF CX ON PX.plob = CX.plob
